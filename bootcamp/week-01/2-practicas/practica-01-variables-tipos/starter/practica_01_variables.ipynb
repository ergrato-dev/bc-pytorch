# %% [markdown]
# # 🏋️ Práctica 01: Variables y Tipos de Datos
#
# **Objetivo**: Practicar creación de variables, tipos de datos y conversiones.
#
# **Tiempo estimado**: 30-40 minutos

# %% [markdown]
# ## 📚 Ejercicio 1: Información Personal
#
# Crea variables para almacenar:
# - Nombre completo (str)
# - Edad (int)
# - Altura en metros (float)
# - Estudiante activo (bool)
#
# Luego muestra la información formateada.

# %%
# ============================================
# TODO: Completa las variables
# ============================================

# Descomenta y completa:
# nombre_completo = "Tu Nombre"
# edad = 0
# altura = 0.0
# es_estudiante = True

# Muestra la información
# print(f"Nombre: {nombre_completo}")
# print(f"Edad: {edad} años")
# print(f"Altura: {altura}m")
# print(f"¿Estudiante?: {es_estudiante}")

# %% [markdown]
# **Resultado esperado**:
# ```
# Nombre: Tu Nombre
# Edad: XX años
# Altura: X.XXm
# ¿Estudiante?: True
# ```

# %% [markdown]
# ## 📚 Ejercicio 2: Calculadora de IMC
#
# Calcula el Índice de Masa Corporal (IMC):
#
# **Fórmula**: `IMC = peso(kg) / altura(m)²`

# %%
# ============================================
# TODO: Calcula el IMC
# ============================================

# Datos de ejemplo
# peso = 70.0  # kg
# altura = 1.75  # metros

# Calcula IMC
# imc = peso / (altura ** 2)

# Muestra resultado redondeado a 2 decimales
# print(f"Peso: {peso}kg")
# print(f"Altura: {altura}m")
# print(f"IMC: {imc:.2f}")

# Interpretación
# if imc < 18.5:
#     print("Clasificación: Bajo peso")
# elif imc < 25:
#     print("Clasificación: Normal")
# elif imc < 30:
#     print("Clasificación: Sobrepeso")
# else:
#     print("Clasificación: Obesidad")

# %% [markdown]
# **Verificación**: Para peso=70kg y altura=1.75m, IMC ≈ 22.86 (Normal)

# %% [markdown]
# ## 📚 Ejercicio 3: Conversión de Tipos
#
# Practica conversiones entre tipos de datos.

# %%
# ============================================
# TODO: Realiza conversiones
# ============================================

# a) String a Int
# edad_str = "25"
# edad_int = int(edad_str)
# print(f"Edad en 5 años: {edad_int + 5}")

# b) String a Float
# precio_str = "99.99"
# precio_float = float(precio_str)
# print(f"Precio con IVA (21%): {precio_float * 1.21:.2f}")

# c) Float a Int (trunca decimales)
# temperatura = 23.8
# temperatura_int = int(temperatura)
# print(f"Temperatura redondeada: {temperatura_int}°C")

# d) Int/Float a String
# numero = 42
# numero_str = str(numero)
# mensaje = "El número es: " + numero_str
# print(mensaje)

# e) Valores a Boolean
# print(f"bool(0) = {bool(0)}")
# print(f"bool(1) = {bool(1)}")
# print(f"bool('') = {bool('')}")
# print(f"bool('Python') = {bool('Python')}")

# %% [markdown]
# ## 📚 Ejercicio 4: Manipulación de Strings
#
# Usa métodos de strings para transformar texto.

# %%
# ============================================
# TODO: Manipula strings
# ============================================

# texto = "  Python es GENIAL para Data Science  "

# a) Mayúsculas y minúsculas
# print(f"Mayúsculas: {texto.upper()}")
# print(f"Minúsculas: {texto.lower()}")
# print(f"Capitalize: {texto.capitalize()}")

# b) Eliminar espacios
# print(f"Sin espacios: '{texto.strip()}'")

# c) Reemplazar
# print(f"Reemplazo: {texto.replace('Python', 'PyTorch')}")

# d) Dividir en palabras
# palabras = texto.split()
# print(f"Palabras: {palabras}")
# print(f"Total palabras: {len(palabras)}")

# e) Concatenación
# lenguaje = "Python"
# version = "3.11"
# completo = lenguaje + " " + version
# print(f"Concatenado: {completo}")

# f) F-strings (mejor forma)
# print(f"Con f-string: {lenguaje} {version}")

# %% [markdown]
# ## 📚 Ejercicio 5: Verificación de Tipos
#
# Usa `type()` e `isinstance()` para verificar tipos.

# %%
# ============================================
# TODO: Verifica tipos
# ============================================

# valor1 = 42
# valor2 = 3.14
# valor3 = "Python"
# valor4 = True
# valor5 = None

# print(f"Tipo de {valor1}: {type(valor1)}")
# print(f"Tipo de {valor2}: {type(valor2)}")
# print(f"Tipo de '{valor3}': {type(valor3)}")
# print(f"Tipo de {valor4}: {type(valor4)}")
# print(f"Tipo de {valor5}: {type(valor5)}")

# print("\n--- isinstance() ---")
# print(f"¿{valor1} es int?: {isinstance(valor1, int)}")
# print(f"¿{valor2} es int?: {isinstance(valor2, int)}")
# print(f"¿{valor2} es float?: {isinstance(valor2, float)}")
# print(f"¿{valor2} es número?: {isinstance(valor2, (int, float))}")

# %% [markdown]
# ## 🎉 ¡Felicitaciones!
#
# Has completado la Práctica 01. Ahora dominas:
# - ✅ Creación de variables con nombres descriptivos
# - ✅ Tipos de datos básicos (int, float, str, bool)
# - ✅ Conversión entre tipos (casting)
# - ✅ Manipulación de strings
# - ✅ Verificación de tipos
#
# **Siguiente paso**: [Práctica 02 - Operadores](../practica-02-operadores/)
