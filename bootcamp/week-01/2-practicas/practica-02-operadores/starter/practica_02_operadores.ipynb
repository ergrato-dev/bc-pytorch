# %% [markdown]
# # 🏋️ Práctica 02: Operadores y Expresiones
#
# **Objetivo**: Dominar operadores aritméticos, comparación, lógicos y de asignación.
#
# **Tiempo estimado**: 30-40 minutos

# %% [markdown]
# ## 📚 Ejercicio 1: Calculadora Aritmética
#
# Implementa una calculadora que realice todas las operaciones aritméticas básicas.

# %%
# ============================================
# TODO: Completa las operaciones
# ============================================

# a = 17
# b = 5

# print(f"Números: a={a}, b={b}\n")

# # Operaciones básicas
# print(f"Suma: {a} + {b} = {a + b}")
# print(f"Resta: {a} - {b} = {a - b}")
# print(f"Multiplicación: {a} * {b} = {a * b}")
# print(f"División: {a} / {b} = {a / b:.2f}")
# print(f"División entera: {a} // {b} = {a // b}")
# print(f"Módulo: {a} % {b} = {a % b}")
# print(f"Potencia: {a} ** 2 = {a ** 2}")

# %% [markdown]
# ## 📚 Ejercicio 2: Par o Impar
#
# Usa el operador módulo para determinar si números son pares o impares.

# %%
# ============================================
# TODO: Verifica paridad
# ============================================

# numeros = [10, 15, 23, 42, 7, 100]

# for numero in numeros:
#     es_par = numero % 2 == 0
#     tipo = "par" if es_par else "impar"
#     print(f"{numero} es {tipo}")

# %% [markdown]
# ## 📚 Ejercicio 3: Comparaciones y Rangos
#
# Verifica si valores están dentro de rangos usando operadores de comparación.

# %%
# ============================================
# TODO: Verifica rangos
# ============================================

# edad = 25

# # Verificar mayoría de edad
# es_mayor = edad >= 18
# print(f"¿Edad {edad} es mayor de edad?: {es_mayor}")

# # Verificar si está en rango 18-65
# en_rango_laboral = edad >= 18 and edad <= 65
# print(f"¿Está en rango laboral (18-65)?: {en_rango_laboral}")

# # Verificar descuento (menores de 12 o mayores de 65)
# tiene_descuento = edad < 12 or edad > 65
# print(f"¿Tiene descuento?: {tiene_descuento}")

# %% [markdown]
# ## 📚 Ejercicio 4: Lógica Booleana
#
# Combina múltiples condiciones con operadores lógicos.

# %%
# ============================================
# TODO: Evalúa condiciones lógicas
# ============================================

# # Sistema de acceso
# tiene_usuario = True
# tiene_contraseña = True
# es_admin = False
# esta_bloqueado = False

# # Puede acceder si tiene usuario Y contraseña Y NO está bloqueado
# puede_acceder = tiene_usuario and tiene_contraseña and not esta_bloqueado
# print(f"¿Puede acceder?: {puede_acceder}")

# # Puede ver panel admin si es admin O tiene permiso especial
# tiene_permiso_especial = True
# puede_ver_admin = es_admin or tiene_permiso_especial
# print(f"¿Puede ver panel admin?: {puede_ver_admin}")

# # Tabla de verdad
# print("\n--- Tabla de Verdad ---")
# print(f"True and True = {True and True}")
# print(f"True and False = {True and False}")
# print(f"True or False = {True or False}")
# print(f"False or False = {False or False}")
# print(f"not True = {not True}")
# print(f"not False = {not False}")

# %% [markdown]
# ## 📚 Ejercicio 5: Operadores de Asignación
#
# Usa operadores compuestos para actualizar variables.

# %%
# ============================================
# TODO: Usa operadores de asignación
# ============================================

# # Contador
# contador = 0
# print(f"Contador inicial: {contador}")

# contador += 1  # contador = contador + 1
# print(f"Después de +=1: {contador}")

# contador += 5
# print(f"Después de +=5: {contador}")

# contador -= 2
# print(f"Después de -=2: {contador}")

# # Acumulador de precio
# total = 100
# print(f"\nTotal inicial: ${total}")

# total *= 1.10  # Aumenta 10%
# print(f"Después de aumentar 10%: ${total:.2f}")

# total /= 2  # Dividir a la mitad
# print(f"Después de dividir a la mitad: ${total:.2f}")

# # Multiplicador
# valor = 1
# print(f"\nValor inicial: {valor}")
# valor *= 2
# print(f"×2: {valor}")
# valor *= 3
# print(f"×3: {valor}")
# valor **= 2
# print(f"^2: {valor}")

# %% [markdown]
# ## 📚 Ejercicio 6: Precedencia de Operadores
#
# Evalúa expresiones complejas entendiendo el orden de operaciones.

# %%
# ============================================
# TODO: Evalúa expresiones con precedencia
# ============================================

# # Expresión 1: Sin paréntesis
# resultado = 2 + 3 * 4
# print(f"2 + 3 * 4 = {resultado}")  # 14, no 20

# # Expresión 2: Con paréntesis
# resultado = (2 + 3) * 4
# print(f"(2 + 3) * 4 = {resultado}")  # 20

# # Expresión 3: Compleja
# resultado = 10 + 5 * 2 - 3 ** 2
# # Orden: 3**2=9, 5*2=10, 10+10=20, 20-9=11
# print(f"10 + 5 * 2 - 3 ** 2 = {resultado}")

# # Expresión 4: División
# resultado = 20 / 4 * 2
# # Orden: izquierda a derecha: 20/4=5, 5*2=10
# print(f"20 / 4 * 2 = {resultado}")

# # Expresión 5: Con comparación y lógicos
# x = 10
# y = 5
# resultado = x > 5 and y < 10 or x == y
# # Orden: comparaciones primero, luego and, luego or
# print(f"x > 5 and y < 10 or x == y = {resultado}")

# %% [markdown]
# ## 🎉 ¡Felicitaciones!
#
# Has completado la Práctica 02. Ahora dominas:
# - ✅ Operadores aritméticos (+, -, *, /, //, %, **)
# - ✅ Operadores de comparación (==, !=, <, >, <=, >=)
# - ✅ Operadores lógicos (and, or, not)
# - ✅ Operadores de asignación (+=, -=, *=, /=, etc.)
# - ✅ Precedencia de operadores
#
# **Siguiente paso**: [Práctica 03 - Control de Flujo](../practica-03-control-flujo/)
