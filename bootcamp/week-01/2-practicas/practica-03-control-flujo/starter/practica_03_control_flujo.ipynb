# %% [markdown]
# # 🏋️ Práctica 03: Control de Flujo
#
# **Objetivo**: Dominar condicionales (if/elif/else) y bucles (for/while).
#
# **Tiempo estimado**: 40-50 minutos

# %% [markdown]
# ## 📚 Ejercicio 1: Clasificador de Edad
#
# Crea un programa que clasifique edades en categorías.

# %%
# ============================================
# TODO: Clasifica edades
# ============================================

# edad = 25

# if edad < 13:
#     categoria = "Niño"
# elif edad < 18:
#     categoria = "Adolescente"
# elif edad < 65:
#     categoria = "Adulto"
# else:
#     categoria = "Adulto Mayor"

# print(f"Con {edad} años, eres: {categoria}")

# %% [markdown]
# ## 📚 Ejercicio 2: FizzBuzz
#
# Imprime números del 1 al 30, pero:
# - "Fizz" si es múltiplo de 3
# - "Buzz" si es múltiplo de 5
# - "FizzBuzz" si es múltiplo de ambos

# %%
# ============================================
# TODO: Implementa FizzBuzz
# ============================================

# for numero in range(1, 31):
#     if numero % 15 == 0:
#         print("FizzBuzz")
#     elif numero % 3 == 0:
#         print("Fizz")
#     elif numero % 5 == 0:
#         print("Buzz")
#     else:
#         print(numero)

# %% [markdown]
# ## 📚 Ejercicio 3: Suma Acumulativa
#
# Suma todos los números del 1 al 100 usando un bucle for.

# %%
# ============================================
# TODO: Suma números del 1 al 100
# ============================================

# suma = 0
# for i in range(1, 101):
#     suma += i
# print(f"La suma de 1 a 100 es: {suma}")

# %% [markdown]
# ## 📚 Ejercicio 4: Tabla de Multiplicar
#
# Imprime la tabla de multiplicar de un número.

# %%
# ============================================
# TODO: Tabla de multiplicar del 7
# ============================================

# numero = 7
# print(f"\nTabla del {numero}:")
# for i in range(1, 11):
#     resultado = numero * i
#     print(f"{numero} x {i} = {resultado}")

# %% [markdown]
# ## 📚 Ejercicio 5: Validación con While
#
# Pide al usuario un número entre 1 y 10. Sigue pidiendo hasta que ingrese un valor válido.

# %%
# ============================================
# TODO: Valida entrada con while
# ============================================

# numero = 0
# while numero < 1 or numero > 10:
#     numero = int(input("Ingresa un número entre 1 y 10: "))
#     if numero < 1 or numero > 10:
#         print("❌ Número inválido. Intenta de nuevo.")
# print(f"✅ ¡Perfecto! Ingresaste {numero}")

# %% [markdown]
# ## 📚 Ejercicio 6: Break y Continue
#
# Usa break y continue para controlar bucles.

# %%
# ============================================
# TODO: Usa break y continue
# ============================================

# # a) Buscar número con break
# for i in range(1, 11):
#     if i == 7:
#         print(f"¡Encontré el {i}!")
#         break
#     print(i)

# print("\n--- Solo impares con continue ---")
# # b) Solo impares con continue
# for i in range(1, 11):
#     if i % 2 == 0:
#         continue
#     print(i)

# %% [markdown]
# ## 📚 Ejercicio 7: Menú Interactivo
#
# Crea un menú simple que se ejecute hasta que el usuario elija salir.

# %%
# ============================================
# TODO: Menú interactivo
# ============================================

# while True:
#     print("\n=== MENÚ ===")
#     print("1. Opción A")
#     print("2. Opción B")
#     print("3. Salir")
#     
#     opcion = input("Elige (1-3): ")
#     
#     if opcion == "1":
#         print("→ Elegiste A")
#     elif opcion == "2":
#         print("→ Elegiste B")
#     elif opcion == "3":
#         print("¡Adiós!")
#         break
#     else:
#         print("❌ Opción inválida")

# %% [markdown]
# ## 🎉 ¡Felicitaciones!
#
# Has completado la Práctica 03. Ahora dominas:
# - ✅ Condicionales if/elif/else
# - ✅ Bucle for con range()
# - ✅ Bucle while
# - ✅ break, continue, pass
#
# **Siguiente paso**: [Práctica 04 - Funciones](../practica-04-funciones/)
