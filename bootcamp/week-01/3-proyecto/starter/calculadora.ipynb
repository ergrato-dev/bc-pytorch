# %% [markdown]
# # 🚀 Proyecto Week 01: Calculadora Interactiva
#
# > **ÚNICO ENTREGABLE OBLIGATORIO** para aprobar la semana.
#
# **Objetivo**: Crear una calculadora interactiva aplicando todos los conceptos de la semana.
#
# **Tiempo estimado**: 5-6 horas

# %% [markdown]
# ## 📋 Estructura del Proyecto
#
# Tu calculadora debe incluir:
# 1. **Funciones matemáticas** (sumar, restar, multiplicar, dividir)
# 2. **Menú interactivo** con opciones
# 3. **Validación de entrada** del usuario
# 4. **Manejo de errores** (división por cero, entradas inválidas)
# 5. **Loop principal** que permita hacer múltiples cálculos

# %% [markdown]
# ## 🔧 Paso 1: Funciones Matemáticas Básicas
#
# Implementa las cuatro operaciones fundamentales.

# %%
# ============================================
# TODO: Implementa las funciones matemáticas
# ============================================

# def sumar(a, b):
#     """
#     Retorna la suma de a y b.
#     
#     Args:
#         a (float): Primer número
#         b (float): Segundo número
#     
#     Returns:
#         float: Resultado de a + b
#     """
#     pass  # Reemplaza con tu código

# def restar(a, b):
#     """
#     Retorna la resta de a - b.
#     
#     Args:
#         a (float): Primer número
#         b (float): Segundo número
#     
#     Returns:
#         float: Resultado de a - b
#     """
#     pass  # Reemplaza con tu código

# def multiplicar(a, b):
#     """
#     Retorna la multiplicación de a * b.
#     
#     Args:
#         a (float): Primer número
#         b (float): Segundo número
#     
#     Returns:
#         float: Resultado de a * b
#     """
#     pass  # Reemplaza con tu código

# def dividir(a, b):
#     """
#     Retorna la división de a / b.
#     Maneja el caso de división por cero.
#     
#     Args:
#         a (float): Numerador
#         b (float): Denominador
#     
#     Returns:
#         float or str: Resultado de a / b o mensaje de error
#     """
#     pass  # Reemplaza con tu código (recuerda validar b != 0)

# %% [markdown]
# ### ✅ Pruebas de las Funciones
#
# Ejecuta estas pruebas para verificar tus funciones:

# %%
# Descomenta después de implementar las funciones

# print("=== Pruebas de Funciones ===")
# print(f"10 + 5 = {sumar(10, 5)}")
# print(f"10 - 5 = {restar(10, 5)}")
# print(f"10 * 5 = {multiplicar(10, 5)}")
# print(f"10 / 5 = {dividir(10, 5)}")
# print(f"10 / 0 = {dividir(10, 0)}")  # Debe mostrar mensaje de error

# %% [markdown]
# ## 🎨 Paso 2: Función para Mostrar el Menú
#
# Crea una función que muestre el menú de opciones.

# %%
# ============================================
# TODO: Implementa la función mostrar_menu()
# ============================================

# def mostrar_menu():
#     """
#     Muestra el menú de opciones de la calculadora.
#     """
#     print("\n" + "="*40)
#     print("   CALCULADORA INTERACTIVA")
#     print("="*40)
#     print("1. Sumar")
#     print("2. Restar")
#     print("3. Multiplicar")
#     print("4. Dividir")
#     print("5. Salir")
#     print("="*40)

# %% [markdown]
# ## 🔢 Paso 3: Función para Obtener Números del Usuario
#
# Crea una función que solicite y valide números del usuario.

# %%
# ============================================
# TODO: Implementa obtener_numeros()
# ============================================

# def obtener_numeros():
#     """
#     Solicita dos números al usuario y los retorna como floats.
#     
#     Returns:
#         tuple: (num1, num2) como floats
#     """
#     # Pista: Usa input() y float()
#     # Ejemplo: num1 = float(input("Ingresa el primer número: "))
#     pass  # Reemplaza con tu código

# %% [markdown]
# ## 🎮 Paso 4: Función Principal (Calculadora)
#
# Implementa el loop principal que coordina todo.

# %%
# ============================================
# TODO: Implementa la función calculadora()
# ============================================

# def calculadora():
#     """
#     Función principal que ejecuta la calculadora interactiva.
#     """
#     while True:
#         mostrar_menu()
#         
#         # Obtener opción del usuario
#         opcion = input("Elige una opción (1-5): ")
#         
#         # Validar opción
#         if opcion == "5":
#             print("\n¡Gracias por usar la calculadora! 👋")
#             break
#         
#         # Verificar que la opción sea válida
#         if opcion not in ["1", "2", "3", "4"]:
#             print("❌ Opción inválida. Intenta de nuevo.")
#             continue
#         
#         # Obtener números del usuario
#         try:
#             num1, num2 = obtener_numeros()
#         except ValueError:
#             print("❌ Error: Debes ingresar números válidos.")
#             continue
#         
#         # Realizar la operación según la opción
#         if opcion == "1":
#             resultado = sumar(num1, num2)
#             operacion = "+"
#         elif opcion == "2":
#             resultado = restar(num1, num2)
#             operacion = "-"
#         elif opcion == "3":
#             resultado = multiplicar(num1, num2)
#             operacion = "*"
#         elif opcion == "4":
#             resultado = dividir(num1, num2)
#             operacion = "/"
#         
#         # Mostrar resultado
#         print(f"\n✅ Resultado: {num1} {operacion} {num2} = {resultado}")
#         input("\nPresiona Enter para continuar...")

# %% [markdown]
# ## ▶️ Ejecutar la Calculadora
#
# Una vez implementadas todas las funciones, ejecuta la calculadora:

# %%
# Descomenta para ejecutar
# calculadora()

# %% [markdown]
# ## 🌟 Paso 5: Funcionalidades Extra (Opcionales)
#
# Implementa al menos una de estas mejoras para obtener puntos adicionales:

# %% [markdown]
# ### Extra 1: Operaciones Avanzadas
#
# Agrega potencia, raíz cuadrada y módulo.

# %%
# ============================================
# EXTRA: Operaciones avanzadas (opcional)
# ============================================

# def potencia(a, b):
#     """Retorna a elevado a la b"""
#     pass

# def raiz_cuadrada(a):
#     """Retorna la raíz cuadrada de a"""
#     pass

# def modulo(a, b):
#     """Retorna el módulo de a % b"""
#     pass

# %% [markdown]
# ### Extra 2: Historial de Operaciones
#
# Guarda y muestra el historial de cálculos.

# %%
# ============================================
# EXTRA: Historial (opcional)
# ============================================

# historial = []

# def agregar_al_historial(operacion, resultado):
#     """Agrega una operación al historial"""
#     pass

# def mostrar_historial():
#     """Muestra el historial de operaciones"""
#     pass

# %% [markdown]
# ## ✅ Checklist Final
#
# Antes de entregar, verifica:
#
# ### Funcionalidad (40 puntos)
# - [ ] Función `sumar()` funciona correctamente
# - [ ] Función `restar()` funciona correctamente
# - [ ] Función `multiplicar()` funciona correctamente
# - [ ] Función `dividir()` funciona y maneja división por cero
# - [ ] Menú se muestra correctamente
# - [ ] Usuario puede elegir opciones
# - [ ] Se obtienen números del usuario correctamente
# - [ ] Calculadora puede hacer múltiples operaciones
# - [ ] Opción "Salir" funciona
# - [ ] Manejo de errores para entradas inválidas
#
# ### Código Limpio (20 puntos)
# - [ ] Código bien organizado en funciones
# - [ ] Nombres de variables descriptivos (snake_case)
# - [ ] Docstrings en todas las funciones
# - [ ] Comentarios explicativos donde sea necesario
# - [ ] Indentación correcta (4 espacios)
#
# ### Resultados (20 puntos)
# - [ ] Todas las operaciones dan resultados correctos
# - [ ] Mensajes claros al usuario
# - [ ] Manejo elegante de errores
# - [ ] Interfaz intuitiva
#
# ### Documentación (20 puntos)
# - [ ] README con conclusiones (crea archivo CONCLUSIONES.md)
# - [ ] Explicación de desafíos encontrados
# - [ ] Capturas de pantalla de ejecución
# - [ ] Código ejecuta sin errores
#
# ### Extras (Hasta 30 puntos adicionales)
# - [ ] Operaciones avanzadas implementadas (+10)
# - [ ] Historial de operaciones (+10)
# - [ ] Validación robusta de entrada (+5)
# - [ ] Interfaz mejorada con emojis/colores (+5)
#
# ---
#
# ## 🎉 ¡Éxito!
#
# Has completado el **Proyecto Week-01**. Este proyecto demuestra que dominas:
# - ✅ Variables y tipos de datos
# - ✅ Operadores aritméticos
# - ✅ Estructuras de control (if/elif/else, while)
# - ✅ Funciones con parámetros y return
# - ✅ Entrada/salida del usuario
# - ✅ Manejo básico de errores
#
# **¡Felicitaciones! Estás listo para Week-02** 🚀
